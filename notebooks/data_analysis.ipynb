# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/symbols.csv")

# %%
df.loc[df['symbol'].str.contains('ETHER')]
# Out:
#             symbol currency categoryName currencyProfit  quoteId  \
# 716   ETHERCLASSIC      ETC          CRT            USD       10
# 2761      ETHEREUM      ETH          CRT            USD       10
#
#       quoteIdCross  marginMode  profitMode  pipsPrecision  contractSize  \
# 716              4         101           5              3             1
# 2761             4         101           5              2             1
#
#       exemode           time  expiration  stopsLevel  precision  swapType  \
# 716         1  1594999658185         NaN           0          3         2
# 2761        1  1594999658556         NaN           0          3         2
#
#       stepRuleId  type  instantMaxVolume groupName       description  \
# 716            4  2764        2147483647    Crypto  Ethereum Classic
# 2761           4  2405        2147483647    Crypto          Ethereum
#
#       longOnly  trailingEnabled  marginHedgedStrong  swapEnable  percentage  \
# ...
